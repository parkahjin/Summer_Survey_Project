# %% [markdown]
# # 1. 연령대별 가장_최근_여름_휴가 건수 비율

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# --- 데이터 생성 코드 ---
options = {'age': ['10대', '20대', '30대', '40대', '50대', '60대 이상'], 'gender': ['남성', '여성'], 'vacation_type': ['해수욕, 물놀이 (바다/섬 여행)', '등산, 캠핑 등 아웃도어 활동 (산/계곡 여행)', '문화생활 (전시, 공연, 역사 탐방, 축제 등)', '도시 관광 (쇼핑, 카페, 시내 구경)', '휴양·힐링 (스파, 리조트, 펜션 휴식)', '맛집 투어 (맛집 탐방, 지역 특산물 체험)', '친척·지인 방문', '기타(결측치 처리)'], 'location_domestic': ['서울', '부산', '대구', '대전', '광주', '울산', '인천', '세종', '강원', '경북', '경남', '전북', '전남', '충북', '충남', '제주'], 'location_overseas': ['동아시아', '동남아시아', '서유럽', '동유럽', '북미', '남미', '중동', '오세아니아', '아프리카'], 'transportation': ['자동차', '버스', '기차', '항공편', '배(선박)', '도보'], 'duration': ['1일', '2~3일', '4~6일', '7일~ 15일', '15일 이상'], 'companions': ['혼자', '가족', '친구', '연인', '직장 동료', '동호회', '기타(결측치 처리)'], 'cost': ['10만 원 이하', '10만~30만 원', '30만~50만 원', '50만~100만 원', '100만 원~200만 원', '200만 원 이상'], 'satisfaction': ['매우 만족', '만족', '보통', '불만족', '매우 불만족']}
age_probs = {'10대': {'age': 0.05, 'vacation_type_p': [0.4, 0.05, 0.1, 0.2, 0.1, 0.1, 0.04, 0.01], 'location_p': [0.7, 0.3], 'transportation_p': [0.2, 0.1, 0.1, 0.25, 0.05, 0.3], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.05, 0.5, 0.35, 0.05, 0.01, 0.03, 0.01], 'cost_p': [0.3, 0.3, 0.2, 0.1, 0.05, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '20대': {'age': 0.25, 'vacation_type_p': [0.3, 0.05, 0.15, 0.2, 0.1, 0.15, 0.04, 0.01], 'location_p': [0.65, 0.35], 'transportation_p': [0.3, 0.1, 0.1, 0.35, 0.05, 0.1], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.15, 0.25, 0.25, 0.25, 0.05, 0.04, 0.01], 'cost_p': [0.1, 0.2, 0.3, 0.2, 0.15, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '30대': {'age': 0.25, 'vacation_type_p': [0.25, 0.1, 0.1, 0.1, 0.25, 0.1, 0.09, 0.01], 'location_p': [0.8, 0.2], 'transportation_p': [0.6, 0.05, 0.1, 0.1, 0.05, 0.1], 'duration_p': [0.05, 0.35, 0.3, 0.2, 0.1], 'companions_p': [0.05, 0.65, 0.15, 0.1, 0.03, 0.01, 0.01], 'cost_p': [0.05, 0.15, 0.25, 0.3, 0.2, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '40대': {'age': 0.2, 'vacation_type_p': [0.2, 0.2, 0.1, 0.05, 0.2, 0.1, 0.14, 0.01], 'location_p': [0.85, 0.15], 'transportation_p': [0.7, 0.1, 0.05, 0.05, 0.05, 0.05], 'duration_p': [0.05, 0.3, 0.3, 0.25, 0.1], 'companions_p': [0.05, 0.7, 0.1, 0.05, 0.05, 0.04, 0.01], 'cost_p': [0.05, 0.1, 0.2, 0.25, 0.25, 0.15], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '50대': {'age': 0.15, 'vacation_type_p': [0.1, 0.3, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.9, 0.1], 'transportation_p': [0.75, 0.1, 0.05, 0.02, 0.05, 0.03], 'duration_p': [0.05, 0.25, 0.3, 0.25, 0.15], 'companions_p': [0.03, 0.6, 0.05, 0.02, 0.2, 0.05, 0.05], 'cost_p': [0.05, 0.1, 0.15, 0.2, 0.25, 0.25], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '60대 이상': {'age': 0.1, 'vacation_type_p': [0.05, 0.35, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.95, 0.05], 'transportation_p': [0.8, 0.1, 0.05, 0.01, 0.03, 0.01], 'duration_p': [0.1, 0.2, 0.25, 0.25, 0.2], 'companions_p': [0.02, 0.5, 0.03, 0.01, 0.3, 0.05, 0.09], 'cost_p': [0.1, 0.1, 0.1, 0.15, 0.25, 0.3], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}}
survey_data = []
for _ in range(500): age = np.random.choice(options['age'], p=[age_probs[a]['age'] for a in options['age']]); probs = age_probs[age]; gender = np.random.choice(options['gender']); vacation_type = np.random.choice(options['vacation_type'], p=probs['vacation_type_p']); location_type = np.random.choice(['국내', '해외'], p=probs['location_p']); location = np.random.choice(options['location_domestic']) if location_type == '국내' else np.random.choice(options['location_overseas']); transportation = np.random.choice(options['transportation'], p=probs['transportation_p']); duration = np.random.choice(options['duration'], p=probs['duration_p']); companions = np.random.choice(options['companions'], p=probs['companions_p']); cost = np.random.choice(options['cost'], p=probs['cost_p']); satisfaction = np.random.choice(options['satisfaction'], p=probs['satisfaction_p']); next_vacation = np.random.choice(options['vacation_type']); survey_data.append([age, gender, vacation_type, location_type, location, transportation, duration, companions, cost, satisfaction, next_vacation])
columns = ['연령대', '성별', '가장_최근_여름_휴가', '휴가_장소_국내_해외', '휴가_장소', '주요_교통수단', '휴가_기간', '함께한_사람', '총_비용', '만족도', '다음_휴가_경험']
df = pd.DataFrame(survey_data, columns=columns)

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
def to_percent(y, position): return f'{y:.0f}%'

# 그래프 생성
column_to_analyze = '가장_최근_여름_휴가'
crosstab_data = pd.crosstab(df['연령대'], df[column_to_analyze])
crosstab_data_norm = crosstab_data.div(crosstab_data.sum(axis=1), axis=0) * 100
fig, ax = plt.subplots(figsize=(14, 8))
crosstab_data_norm.plot(kind='bar', ax=ax, rot=0)
plt.title(f'연령대별 {column_to_analyze} 건수 비율', fontsize=16)
plt.xlabel('연령대', fontsize=12)
plt.ylabel('비율', fontsize=12)
formatter = FuncFormatter(to_percent)
ax.yaxis.set_major_formatter(formatter)
plt.legend(title=column_to_analyze, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout(rect=[0, 0, 0.95, 1])
plt.savefig(f'연령대별_{column_to_analyze}_그룹_막대_그래프.png')
print(f"'연령대별_{column_to_analyze}_그룹_막대_그래프.png' 파일이 생성되었습니다.")
# Out:
# '연령대별_가장_최근_여름_휴가_그룹_막대_그래프.png' 파일이 생성되었습니다.

# %% [markdown]
# # 2. 연령대별 다음 희망_휴가_건수 비율

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# --- 데이터 생성 코드 ---
options = {'age': ['10대', '20대', '30대', '40대', '50대', '60대 이상'], 'gender': ['남성', '여성'], 'vacation_type': ['해수욕, 물놀이 (바다/섬 여행)', '등산, 캠핑 등 아웃도어 활동 (산/계곡 여행)', '문화생활 (전시, 공연, 역사 탐방, 축제 등)', '도시 관광 (쇼핑, 카페, 시내 구경)', '휴양·힐링 (스파, 리조트, 펜션 휴식)', '맛집 투어 (맛집 탐방, 지역 특산물 체험)', '친척·지인 방문', '기타(결측치 처리)'], 'location_domestic': ['서울', '부산', '대구', '대전', '광주', '울산', '인천', '세종', '강원', '경북', '경남', '전북', '전남', '충북', '충남', '제주'], 'location_overseas': ['동아시아', '동남아시아', '서유럽', '동유럽', '북미', '남미', '중동', '오세아니아', '아프리카'], 'transportation': ['자동차', '버스', '기차', '항공편', '배(선박)', '도보'], 'duration': ['1일', '2~3일', '4~6일', '7일~ 15일', '15일 이상'], 'companions': ['혼자', '가족', '친구', '연인', '직장 동료', '동호회', '기타(결측치 처리)'], 'cost': ['10만 원 이하', '10만~30만 원', '30만~50만 원', '50만~100만 원', '100만 원~200만 원', '200만 원 이상'], 'satisfaction': ['매우 만족', '만족', '보통', '불만족', '매우 불만족']}
age_probs = {'10대': {'age': 0.05, 'vacation_type_p': [0.4, 0.05, 0.1, 0.2, 0.1, 0.1, 0.04, 0.01], 'location_p': [0.7, 0.3], 'transportation_p': [0.2, 0.1, 0.1, 0.25, 0.05, 0.3], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.05, 0.5, 0.35, 0.05, 0.01, 0.03, 0.01], 'cost_p': [0.3, 0.3, 0.2, 0.1, 0.05, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '20대': {'age': 0.25, 'vacation_type_p': [0.3, 0.05, 0.15, 0.2, 0.1, 0.15, 0.04, 0.01], 'location_p': [0.65, 0.35], 'transportation_p': [0.3, 0.1, 0.1, 0.35, 0.05, 0.1], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.15, 0.25, 0.25, 0.25, 0.05, 0.04, 0.01], 'cost_p': [0.1, 0.2, 0.3, 0.2, 0.15, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '30대': {'age': 0.25, 'vacation_type_p': [0.25, 0.1, 0.1, 0.1, 0.25, 0.1, 0.09, 0.01], 'location_p': [0.8, 0.2], 'transportation_p': [0.6, 0.05, 0.1, 0.1, 0.05, 0.1], 'duration_p': [0.05, 0.35, 0.3, 0.2, 0.1], 'companions_p': [0.05, 0.65, 0.15, 0.1, 0.03, 0.01, 0.01], 'cost_p': [0.05, 0.15, 0.25, 0.3, 0.2, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '40대': {'age': 0.2, 'vacation_type_p': [0.2, 0.2, 0.1, 0.05, 0.2, 0.1, 0.14, 0.01], 'location_p': [0.85, 0.15], 'transportation_p': [0.7, 0.1, 0.05, 0.05, 0.05, 0.05], 'duration_p': [0.05, 0.3, 0.3, 0.25, 0.1], 'companions_p': [0.05, 0.7, 0.1, 0.05, 0.05, 0.04, 0.01], 'cost_p': [0.05, 0.1, 0.2, 0.25, 0.25, 0.15], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '50대': {'age': 0.15, 'vacation_type_p': [0.1, 0.3, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.9, 0.1], 'transportation_p': [0.75, 0.1, 0.05, 0.02, 0.05, 0.03], 'duration_p': [0.05, 0.25, 0.3, 0.25, 0.15], 'companions_p': [0.03, 0.6, 0.05, 0.02, 0.2, 0.05, 0.05], 'cost_p': [0.05, 0.1, 0.15, 0.2, 0.25, 0.25], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '60대 이상': {'age': 0.1, 'vacation_type_p': [0.05, 0.35, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.95, 0.05], 'transportation_p': [0.8, 0.1, 0.05, 0.01, 0.03, 0.01], 'duration_p': [0.1, 0.2, 0.25, 0.25, 0.2], 'companions_p': [0.02, 0.5, 0.03, 0.01, 0.3, 0.05, 0.09], 'cost_p': [0.1, 0.1, 0.1, 0.15, 0.25, 0.3], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}}
survey_data = []
for _ in range(500): age = np.random.choice(options['age'], p=[age_probs[a]['age'] for a in options['age']]); probs = age_probs[age]; gender = np.random.choice(options['gender']); vacation_type = np.random.choice(options['vacation_type'], p=probs['vacation_type_p']); location_type = np.random.choice(['국내', '해외'], p=probs['location_p']); location = np.random.choice(options['location_domestic']) if location_type == '국내' else np.random.choice(options['location_overseas']); transportation = np.random.choice(options['transportation'], p=probs['transportation_p']); duration = np.random.choice(options['duration'], p=probs['duration_p']); companions = np.random.choice(options['companions'], p=probs['companions_p']); cost = np.random.choice(options['cost'], p=probs['cost_p']); satisfaction = np.random.choice(options['satisfaction'], p=probs['satisfaction_p']); next_vacation = np.random.choice(options['vacation_type']); survey_data.append([age, gender, vacation_type, location_type, location, transportation, duration, companions, cost, satisfaction, next_vacation])
columns = ['연령대', '성별', '가장_최근_여름_휴가', '휴가_장소_국내_해외', '휴가_장소', '주요_교통수단', '휴가_기간', '함께한_사람', '총_비용', '만족도', '다음_휴가_경험']
df = pd.DataFrame(survey_data, columns=columns)

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
def to_percent(y, position): return f'{y:.0f}%'

# 그래프 생성
column_to_analyze = '다음_휴가_경험'
crosstab_data = pd.crosstab(df['연령대'], df[column_to_analyze])
crosstab_data_norm = crosstab_data.div(crosstab_data.sum(axis=1), axis=0) * 100
fig, ax = plt.subplots(figsize=(14, 8))
crosstab_data_norm.plot(kind='bar', ax=ax, rot=0)
plt.title('연령대별 다음_희망_휴가 건수 비율', fontsize=16)
plt.xlabel('연령대', fontsize=12)
plt.ylabel('비율', fontsize=12)
formatter = FuncFormatter(to_percent)
ax.yaxis.set_major_formatter(formatter)
plt.legend(title='다음_희망_휴가', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout(rect=[0, 0, 0.95, 1])
plt.savefig('연령대별_다음_희망_휴가_건수_비율.png')
print("'연령대별_다음_희망_휴가_건수_비율.png' 파일이 생성되었습니다.")
# Out:
# '연령대별_다음_희망_휴가_건수_비율.png' 파일이 생성되었습니다.

# %% [markdown]
# # 3. 연령대별 만족도 건수 비율

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# --- 데이터 생성 코드 ---
options = {'age': ['10대', '20대', '30대', '40대', '50대', '60대 이상'], 'gender': ['남성', '여성'], 'vacation_type': ['해수욕, 물놀이 (바다/섬 여행)', '등산, 캠핑 등 아웃도어 활동 (산/계곡 여행)', '문화생활 (전시, 공연, 역사 탐방, 축제 등)', '도시 관광 (쇼핑, 카페, 시내 구경)', '휴양·힐링 (스파, 리조트, 펜션 휴식)', '맛집 투어 (맛집 탐방, 지역 특산물 체험)', '친척·지인 방문', '기타(결측치 처리)'], 'location_domestic': ['서울', '부산', '대구', '대전', '광주', '울산', '인천', '세종', '강원', '경북', '경남', '전북', '전남', '충북', '충남', '제주'], 'location_overseas': ['동아시아', '동남아시아', '서유럽', '동유럽', '북미', '남미', '중동', '오세아니아', '아프리카'], 'transportation': ['자동차', '버스', '기차', '항공편', '배(선박)', '도보'], 'duration': ['1일', '2~3일', '4~6일', '7일~ 15일', '15일 이상'], 'companions': ['혼자', '가족', '친구', '연인', '직장 동료', '동호회', '기타(결측치 처리)'], 'cost': ['10만 원 이하', '10만~30만 원', '30만~50만 원', '50만~100만 원', '100만 원~200만 원', '200만 원 이상'], 'satisfaction': ['매우 만족', '만족', '보통', '불만족', '매우 불만족']}
age_probs = {'10대': {'age': 0.05, 'vacation_type_p': [0.4, 0.05, 0.1, 0.2, 0.1, 0.1, 0.04, 0.01], 'location_p': [0.7, 0.3], 'transportation_p': [0.2, 0.1, 0.1, 0.25, 0.05, 0.3], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.05, 0.5, 0.35, 0.05, 0.01, 0.03, 0.01], 'cost_p': [0.3, 0.3, 0.2, 0.1, 0.05, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '20대': {'age': 0.25, 'vacation_type_p': [0.3, 0.05, 0.15, 0.2, 0.1, 0.15, 0.04, 0.01], 'location_p': [0.65, 0.35], 'transportation_p': [0.3, 0.1, 0.1, 0.35, 0.05, 0.1], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.15, 0.25, 0.25, 0.25, 0.05, 0.04, 0.01], 'cost_p': [0.1, 0.2, 0.3, 0.2, 0.15, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '30대': {'age': 0.25, 'vacation_type_p': [0.25, 0.1, 0.1, 0.1, 0.25, 0.1, 0.09, 0.01], 'location_p': [0.8, 0.2], 'transportation_p': [0.6, 0.05, 0.1, 0.1, 0.05, 0.1], 'duration_p': [0.05, 0.35, 0.3, 0.2, 0.1], 'companions_p': [0.05, 0.65, 0.15, 0.1, 0.03, 0.01, 0.01], 'cost_p': [0.05, 0.15, 0.25, 0.3, 0.2, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '40대': {'age': 0.2, 'vacation_type_p': [0.2, 0.2, 0.1, 0.05, 0.2, 0.1, 0.14, 0.01], 'location_p': [0.85, 0.15], 'transportation_p': [0.7, 0.1, 0.05, 0.05, 0.05, 0.05], 'duration_p': [0.05, 0.3, 0.3, 0.25, 0.1], 'companions_p': [0.05, 0.7, 0.1, 0.05, 0.05, 0.04, 0.01], 'cost_p': [0.05, 0.1, 0.2, 0.25, 0.25, 0.15], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '50대': {'age': 0.15, 'vacation_type_p': [0.1, 0.3, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.9, 0.1], 'transportation_p': [0.75, 0.1, 0.05, 0.02, 0.05, 0.03], 'duration_p': [0.05, 0.25, 0.3, 0.25, 0.15], 'companions_p': [0.03, 0.6, 0.05, 0.02, 0.2, 0.05, 0.05], 'cost_p': [0.05, 0.1, 0.15, 0.2, 0.25, 0.25], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '60대 이상': {'age': 0.1, 'vacation_type_p': [0.05, 0.35, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.95, 0.05], 'transportation_p': [0.8, 0.1, 0.05, 0.01, 0.03, 0.01], 'duration_p': [0.1, 0.2, 0.25, 0.25, 0.2], 'companions_p': [0.02, 0.5, 0.03, 0.01, 0.3, 0.05, 0.09], 'cost_p': [0.1, 0.1, 0.1, 0.15, 0.25, 0.3], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}}
survey_data = []
for _ in range(500): age = np.random.choice(options['age'], p=[age_probs[a]['age'] for a in options['age']]); probs = age_probs[age]; gender = np.random.choice(options['gender']); vacation_type = np.random.choice(options['vacation_type'], p=probs['vacation_type_p']); location_type = np.random.choice(['국내', '해외'], p=probs['location_p']); location = np.random.choice(options['location_domestic']) if location_type == '국내' else np.random.choice(options['location_overseas']); transportation = np.random.choice(options['transportation'], p=probs['transportation_p']); duration = np.random.choice(options['duration'], p=probs['duration_p']); companions = np.random.choice(options['companions'], p=probs['companions_p']); cost = np.random.choice(options['cost'], p=probs['cost_p']); satisfaction = np.random.choice(options['satisfaction'], p=probs['satisfaction_p']); next_vacation = np.random.choice(options['vacation_type']); survey_data.append([age, gender, vacation_type, location_type, location, transportation, duration, companions, cost, satisfaction, next_vacation])
columns = ['연령대', '성별', '가장_최근_여름_휴가', '휴가_장소_국내_해외', '휴가_장소', '주요_교통수단', '휴가_기간', '함께한_사람', '총_비용', '만족도', '다음_휴가_경험']
df = pd.DataFrame(survey_data, columns=columns)

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
def to_percent(y, position): return f'{y:.0f}%'

# 그래프 생성
column_to_analyze = '만족도'
crosstab_data = pd.crosstab(df['연령대'], df[column_to_analyze])
crosstab_data_norm = crosstab_data.div(crosstab_data.sum(axis=1), axis=0) * 100
fig, ax = plt.subplots(figsize=(14, 8))
crosstab_data_norm.plot(kind='bar', ax=ax, rot=0)
plt.title(f'연령대별 {column_to_analyze} 선택 비율', fontsize=16)
plt.xlabel('연령대', fontsize=12)
plt.ylabel('비율', fontsize=12)
formatter = FuncFormatter(to_percent)
ax.yaxis.set_major_formatter(formatter)
plt.legend(title=column_to_analyze, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout(rect=[0, 0, 0.95, 1])
plt.savefig(f'연령대별_{column_to_analyze}_그룹_막대_그래프.png')
print(f"'연령대별_{column_to_analyze}_그룹_막대_그래프.png' 파일이 생성되었습니다.")
# Out:
# '연령대별_만족도_그룹_막대_그래프.png' 파일이 생성되었습니다.

# %% [markdown]
# # 4. 연령대별 성별 건수 비율

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# --- 데이터 생성 코드 ---
options = {'age': ['10대', '20대', '30대', '40대', '50대', '60대 이상'], 'gender': ['남성', '여성'], 'vacation_type': ['해수욕, 물놀이 (바다/섬 여행)', '등산, 캠핑 등 아웃도어 활동 (산/계곡 여행)', '문화생활 (전시, 공연, 역사 탐방, 축제 등)', '도시 관광 (쇼핑, 카페, 시내 구경)', '휴양·힐링 (스파, 리조트, 펜션 휴식)', '맛집 투어 (맛집 탐방, 지역 특산물 체험)', '친척·지인 방문', '기타(결측치 처리)'], 'location_domestic': ['서울', '부산', '대구', '대전', '광주', '울산', '인천', '세종', '강원', '경북', '경남', '전북', '전남', '충북', '충남', '제주'], 'location_overseas': ['동아시아', '동남아시아', '서유럽', '동유럽', '북미', '남미', '중동', '오세아니아', '아프리카'], 'transportation': ['자동차', '버스', '기차', '항공편', '배(선박)', '도보'], 'duration': ['1일', '2~3일', '4~6일', '7일~ 15일', '15일 이상'], 'companions': ['혼자', '가족', '친구', '연인', '직장 동료', '동호회', '기타(결측치 처리)'], 'cost': ['10만 원 이하', '10만~30만 원', '30만~50만 원', '50만~100만 원', '100만 원~200만 원', '200만 원 이상'], 'satisfaction': ['매우 만족', '만족', '보통', '불만족', '매우 불만족']}
age_probs = {'10대': {'age': 0.05, 'vacation_type_p': [0.4, 0.05, 0.1, 0.2, 0.1, 0.1, 0.04, 0.01], 'location_p': [0.7, 0.3], 'transportation_p': [0.2, 0.1, 0.1, 0.25, 0.05, 0.3], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.05, 0.5, 0.35, 0.05, 0.01, 0.03, 0.01], 'cost_p': [0.3, 0.3, 0.2, 0.1, 0.05, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '20대': {'age': 0.25, 'vacation_type_p': [0.3, 0.05, 0.15, 0.2, 0.1, 0.15, 0.04, 0.01], 'location_p': [0.65, 0.35], 'transportation_p': [0.3, 0.1, 0.1, 0.35, 0.05, 0.1], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.15, 0.25, 0.25, 0.25, 0.05, 0.04, 0.01], 'cost_p': [0.1, 0.2, 0.3, 0.2, 0.15, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '30대': {'age': 0.25, 'vacation_type_p': [0.25, 0.1, 0.1, 0.1, 0.25, 0.1, 0.09, 0.01], 'location_p': [0.8, 0.2], 'transportation_p': [0.6, 0.05, 0.1, 0.1, 0.05, 0.1], 'duration_p': [0.05, 0.35, 0.3, 0.2, 0.1], 'companions_p': [0.05, 0.65, 0.15, 0.1, 0.03, 0.01, 0.01], 'cost_p': [0.05, 0.15, 0.25, 0.3, 0.2, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '40대': {'age': 0.2, 'vacation_type_p': [0.2, 0.2, 0.1, 0.05, 0.2, 0.1, 0.14, 0.01], 'location_p': [0.85, 0.15], 'transportation_p': [0.7, 0.1, 0.05, 0.05, 0.05, 0.05], 'duration_p': [0.05, 0.3, 0.3, 0.25, 0.1], 'companions_p': [0.05, 0.7, 0.1, 0.05, 0.05, 0.04, 0.01], 'cost_p': [0.05, 0.1, 0.2, 0.25, 0.25, 0.15], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '50대': {'age': 0.15, 'vacation_type_p': [0.1, 0.3, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.9, 0.1], 'transportation_p': [0.75, 0.1, 0.05, 0.02, 0.05, 0.03], 'duration_p': [0.05, 0.25, 0.3, 0.25, 0.15], 'companions_p': [0.03, 0.6, 0.05, 0.02, 0.2, 0.05, 0.05], 'cost_p': [0.05, 0.1, 0.15, 0.2, 0.25, 0.25], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '60대 이상': {'age': 0.1, 'vacation_type_p': [0.05, 0.35, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.95, 0.05], 'transportation_p': [0.8, 0.1, 0.05, 0.01, 0.03, 0.01], 'duration_p': [0.1, 0.2, 0.25, 0.25, 0.2], 'companions_p': [0.02, 0.5, 0.03, 0.01, 0.3, 0.05, 0.09], 'cost_p': [0.1, 0.1, 0.1, 0.15, 0.25, 0.3], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}}
survey_data = []
for _ in range(500): age = np.random.choice(options['age'], p=[age_probs[a]['age'] for a in options['age']]); probs = age_probs[age]; gender = np.random.choice(options['gender']); vacation_type = np.random.choice(options['vacation_type'], p=probs['vacation_type_p']); location_type = np.random.choice(['국내', '해외'], p=probs['location_p']); location = np.random.choice(options['location_domestic']) if location_type == '국내' else np.random.choice(options['location_overseas']); transportation = np.random.choice(options['transportation'], p=probs['transportation_p']); duration = np.random.choice(options['duration'], p=probs['duration_p']); companions = np.random.choice(options['companions'], p=probs['companions_p']); cost = np.random.choice(options['cost'], p=probs['cost_p']); satisfaction = np.random.choice(options['satisfaction'], p=probs['satisfaction_p']); next_vacation = np.random.choice(options['vacation_type']); survey_data.append([age, gender, vacation_type, location_type, location, transportation, duration, companions, cost, satisfaction, next_vacation])
columns = ['연령대', '성별', '가장_최근_여름_휴가', '휴가_장소_국내_해외', '휴가_장소', '주요_교통수단', '휴가_기간', '함께한_사람', '총_비용', '만족도', '다음_휴가_경험']
df = pd.DataFrame(survey_data, columns=columns)

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
def to_percent(y, position): return f'{y:.0f}%'

# 그래프 생성
column_to_analyze = '성별'
crosstab_data = pd.crosstab(df['연령대'], df[column_to_analyze])
crosstab_data_norm = crosstab_data.div(crosstab_data.sum(axis=1), axis=0) * 100
fig, ax = plt.subplots(figsize=(10, 6))
crosstab_data_norm.plot(kind='bar', ax=ax, rot=0)
plt.title(f'연령대별 {column_to_analyze} 선택 비율', fontsize=16)
plt.xlabel('연령대', fontsize=12)
plt.ylabel('비율', fontsize=12)
formatter = FuncFormatter(to_percent)
ax.yaxis.set_major_formatter(formatter)
plt.legend(title=column_to_analyze, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout(rect=[0, 0, 0.95, 1])
plt.savefig(f'연령대별_{column_to_analyze}_그룹_막대_그래프.png')
print(f"'연령대별_{column_to_analyze}_그룹_막대_그래프.png' 파일이 생성되었습니다.")
# Out:
# '연령대별_성별_그룹_막대_그래프.png' 파일이 생성되었습니다.

# %% [markdown]
# # 5. 연령대별 총_비용 건수 비율

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# --- 데이터 생성 코드 ---
options = {'age': ['10대', '20대', '30대', '40대', '50대', '60대 이상'], 'gender': ['남성', '여성'], 'vacation_type': ['해수욕, 물놀이 (바다/섬 여행)', '등산, 캠핑 등 아웃도어 활동 (산/계곡 여행)', '문화생활 (전시, 공연, 역사 탐방, 축제 등)', '도시 관광 (쇼핑, 카페, 시내 구경)', '휴양·힐링 (스파, 리조트, 펜션 휴식)', '맛집 투어 (맛집 탐방, 지역 특산물 체험)', '친척·지인 방문', '기타(결측치 처리)'], 'location_domestic': ['서울', '부산', '대구', '대전', '광주', '울산', '인천', '세종', '강원', '경북', '경남', '전북', '전남', '충북', '충남', '제주'], 'location_overseas': ['동아시아', '동남아시아', '서유럽', '동유럽', '북미', '남미', '중동', '오세아니아', '아프리카'], 'transportation': ['자동차', '버스', '기차', '항공편', '배(선박)', '도보'], 'duration': ['1일', '2~3일', '4~6일', '7일~ 15일', '15일 이상'], 'companions': ['혼자', '가족', '친구', '연인', '직장 동료', '동호회', '기타(결측치 처리)'], 'cost': ['10만 원 이하', '10만~30만 원', '30만~50만 원', '50만~100만 원', '100만 원~200만 원', '200만 원 이상'], 'satisfaction': ['매우 만족', '만족', '보통', '불만족', '매우 불만족']}
age_probs = {'10대': {'age': 0.05, 'vacation_type_p': [0.4, 0.05, 0.1, 0.2, 0.1, 0.1, 0.04, 0.01], 'location_p': [0.7, 0.3], 'transportation_p': [0.2, 0.1, 0.1, 0.25, 0.05, 0.3], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.05, 0.5, 0.35, 0.05, 0.01, 0.03, 0.01], 'cost_p': [0.3, 0.3, 0.2, 0.1, 0.05, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '20대': {'age': 0.25, 'vacation_type_p': [0.3, 0.05, 0.15, 0.2, 0.1, 0.15, 0.04, 0.01], 'location_p': [0.65, 0.35], 'transportation_p': [0.3, 0.1, 0.1, 0.35, 0.05, 0.1], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.15, 0.25, 0.25, 0.25, 0.05, 0.04, 0.01], 'cost_p': [0.1, 0.2, 0.3, 0.2, 0.15, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '30대': {'age': 0.25, 'vacation_type_p': [0.25, 0.1, 0.1, 0.1, 0.25, 0.1, 0.09, 0.01], 'location_p': [0.8, 0.2], 'transportation_p': [0.6, 0.05, 0.1, 0.1, 0.05, 0.1], 'duration_p': [0.05, 0.35, 0.3, 0.2, 0.1], 'companions_p': [0.05, 0.65, 0.15, 0.1, 0.03, 0.01, 0.01], 'cost_p': [0.05, 0.15, 0.25, 0.3, 0.2, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '40대': {'age': 0.2, 'vacation_type_p': [0.2, 0.2, 0.1, 0.05, 0.2, 0.1, 0.14, 0.01], 'location_p': [0.85, 0.15], 'transportation_p': [0.7, 0.1, 0.05, 0.05, 0.05, 0.05], 'duration_p': [0.05, 0.3, 0.3, 0.25, 0.1], 'companions_p': [0.05, 0.7, 0.1, 0.05, 0.05, 0.04, 0.01], 'cost_p': [0.05, 0.1, 0.2, 0.25, 0.25, 0.15], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '50대': {'age': 0.15, 'vacation_type_p': [0.1, 0.3, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.9, 0.1], 'transportation_p': [0.75, 0.1, 0.05, 0.02, 0.05, 0.03], 'duration_p': [0.05, 0.25, 0.3, 0.25, 0.15], 'companions_p': [0.03, 0.6, 0.05, 0.02, 0.2, 0.05, 0.05], 'cost_p': [0.05, 0.1, 0.15, 0.2, 0.25, 0.25], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '60대 이상': {'age': 0.1, 'vacation_type_p': [0.05, 0.35, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.95, 0.05], 'transportation_p': [0.8, 0.1, 0.05, 0.01, 0.03, 0.01], 'duration_p': [0.1, 0.2, 0.25, 0.25, 0.2], 'companions_p': [0.02, 0.5, 0.03, 0.01, 0.3, 0.05, 0.09], 'cost_p': [0.1, 0.1, 0.1, 0.15, 0.25, 0.3], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}}
survey_data = []
for _ in range(500): age = np.random.choice(options['age'], p=[age_probs[a]['age'] for a in options['age']]); probs = age_probs[age]; gender = np.random.choice(options['gender']); vacation_type = np.random.choice(options['vacation_type'], p=probs['vacation_type_p']); location_type = np.random.choice(['국내', '해외'], p=probs['location_p']); location = np.random.choice(options['location_domestic']) if location_type == '국내' else np.random.choice(options['location_overseas']); transportation = np.random.choice(options['transportation'], p=probs['transportation_p']); duration = np.random.choice(options['duration'], p=probs['duration_p']); companions = np.random.choice(options['companions'], p=probs['companions_p']); cost = np.random.choice(options['cost'], p=probs['cost_p']); satisfaction = np.random.choice(options['satisfaction'], p=probs['satisfaction_p']); next_vacation = np.random.choice(options['vacation_type']); survey_data.append([age, gender, vacation_type, location_type, location, transportation, duration, companions, cost, satisfaction, next_vacation])
columns = ['연령대', '성별', '가장_최근_여름_휴가', '휴가_장소_국내_해외', '휴가_장소', '주요_교통수단', '휴가_기간', '함께한_사람', '총_비용', '만족도', '다음_휴가_경험']
df = pd.DataFrame(survey_data, columns=columns)

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
def to_percent(y, position): return f'{y:.0f}%'

# 그래프 생성
column_to_analyze = '총_비용'
crosstab_data = pd.crosstab(df['연령대'], df[column_to_analyze])
crosstab_data_norm = crosstab_data.div(crosstab_data.sum(axis=1), axis=0) * 100
fig, ax = plt.subplots(figsize=(14, 8))
crosstab_data_norm.plot(kind='bar', ax=ax, rot=0)
plt.title(f'연령대별 {column_to_analyze} 선택 비율', fontsize=16)
plt.xlabel('연령대', fontsize=12)
plt.ylabel('비율', fontsize=12)
formatter = FuncFormatter(to_percent)
ax.yaxis.set_major_formatter(formatter)
plt.legend(title=column_to_analyze, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout(rect=[0, 0, 0.95, 1])
plt.savefig(f'연령대별_{column_to_analyze}_그룹_막대_그래프.png')
print(f"'연령대별_{column_to_analyze}_그룹_막대_그래프.png' 파일이 생성되었습니다.")
# Out:
# '연령대별_총_비용_그룹_막대_그래프.png' 파일이 생성되었습니다.

# %% [markdown]
# # 6. 연령대별 주요_교통수단 건수 비율

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# --- 데이터 생성 코드 ---
options = {'age': ['10대', '20대', '30대', '40대', '50대', '60대 이상'], 'gender': ['남성', '여성'], 'vacation_type': ['해수욕, 물놀이 (바다/섬 여행)', '등산, 캠핑 등 아웃도어 활동 (산/계곡 여행)', '문화생활 (전시, 공연, 역사 탐방, 축제 등)', '도시 관광 (쇼핑, 카페, 시내 구경)', '휴양·힐링 (스파, 리조트, 펜션 휴식)', '맛집 투어 (맛집 탐방, 지역 특산물 체험)', '친척·지인 방문', '기타(결측치 처리)'], 'location_domestic': ['서울', '부산', '대구', '대전', '광주', '울산', '인천', '세종', '강원', '경북', '경남', '전북', '전남', '충북', '충남', '제주'], 'location_overseas': ['동아시아', '동남아시아', '서유럽', '동유럽', '북미', '남미', '중동', '오세아니아', '아프리카'], 'transportation': ['자동차', '버스', '기차', '항공편', '배(선박)', '도보'], 'duration': ['1일', '2~3일', '4~6일', '7일~ 15일', '15일 이상'], 'companions': ['혼자', '가족', '친구', '연인', '직장 동료', '동호회', '기타(결측치 처리)'], 'cost': ['10만 원 이하', '10만~30만 원', '30만~50만 원', '50만~100만 원', '100만 원~200만 원', '200만 원 이상'], 'satisfaction': ['매우 만족', '만족', '보통', '불만족', '매우 불만족']}
age_probs = {'10대': {'age': 0.05, 'vacation_type_p': [0.4, 0.05, 0.1, 0.2, 0.1, 0.1, 0.04, 0.01], 'location_p': [0.7, 0.3], 'transportation_p': [0.2, 0.1, 0.1, 0.25, 0.05, 0.3], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.05, 0.5, 0.35, 0.05, 0.01, 0.03, 0.01], 'cost_p': [0.3, 0.3, 0.2, 0.1, 0.05, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '20대': {'age': 0.25, 'vacation_type_p': [0.3, 0.05, 0.15, 0.2, 0.1, 0.15, 0.04, 0.01], 'location_p': [0.65, 0.35], 'transportation_p': [0.3, 0.1, 0.1, 0.35, 0.05, 0.1], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.15, 0.25, 0.25, 0.25, 0.05, 0.04, 0.01], 'cost_p': [0.1, 0.2, 0.3, 0.2, 0.15, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '30대': {'age': 0.25, 'vacation_type_p': [0.25, 0.1, 0.1, 0.1, 0.25, 0.1, 0.09, 0.01], 'location_p': [0.8, 0.2], 'transportation_p': [0.6, 0.05, 0.1, 0.1, 0.05, 0.1], 'duration_p': [0.05, 0.35, 0.3, 0.2, 0.1], 'companions_p': [0.05, 0.65, 0.15, 0.1, 0.03, 0.01, 0.01], 'cost_p': [0.05, 0.15, 0.25, 0.3, 0.2, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '40대': {'age': 0.2, 'vacation_type_p': [0.2, 0.2, 0.1, 0.05, 0.2, 0.1, 0.14, 0.01], 'location_p': [0.85, 0.15], 'transportation_p': [0.7, 0.1, 0.05, 0.05, 0.05, 0.05], 'duration_p': [0.05, 0.3, 0.3, 0.25, 0.1], 'companions_p': [0.05, 0.7, 0.1, 0.05, 0.05, 0.04, 0.01], 'cost_p': [0.05, 0.1, 0.2, 0.25, 0.25, 0.15], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '50대': {'age': 0.15, 'vacation_type_p': [0.1, 0.3, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.9, 0.1], 'transportation_p': [0.75, 0.1, 0.05, 0.02, 0.05, 0.03], 'duration_p': [0.05, 0.25, 0.3, 0.25, 0.15], 'companions_p': [0.03, 0.6, 0.05, 0.02, 0.2, 0.05, 0.05], 'cost_p': [0.05, 0.1, 0.15, 0.2, 0.25, 0.25], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '60대 이상': {'age': 0.1, 'vacation_type_p': [0.05, 0.35, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.95, 0.05], 'transportation_p': [0.8, 0.1, 0.05, 0.01, 0.03, 0.01], 'duration_p': [0.1, 0.2, 0.25, 0.25, 0.2], 'companions_p': [0.02, 0.5, 0.03, 0.01, 0.3, 0.05, 0.09], 'cost_p': [0.1, 0.1, 0.1, 0.15, 0.25, 0.3], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}}
survey_data = []
for _ in range(500): age = np.random.choice(options['age'], p=[age_probs[a]['age'] for a in options['age']]); probs = age_probs[age]; gender = np.random.choice(options['gender']); vacation_type = np.random.choice(options['vacation_type'], p=probs['vacation_type_p']); location_type = np.random.choice(['국내', '해외'], p=probs['location_p']); location = np.random.choice(options['location_domestic']) if location_type == '국내' else np.random.choice(options['location_overseas']); transportation = np.random.choice(options['transportation'], p=probs['transportation_p']); duration = np.random.choice(options['duration'], p=probs['duration_p']); companions = np.random.choice(options['companions'], p=probs['companions_p']); cost = np.random.choice(options['cost'], p=probs['cost_p']); satisfaction = np.random.choice(options['satisfaction'], p=probs['satisfaction_p']); next_vacation = np.random.choice(options['vacation_type']); survey_data.append([age, gender, vacation_type, location_type, location, transportation, duration, companions, cost, satisfaction, next_vacation])
columns = ['연령대', '성별', '가장_최근_여름_휴가', '휴가_장소_국내_해외', '휴가_장소', '주요_교통수단', '휴가_기간', '함께한_사람', '총_비용', '만족도', '다음_휴가_경험']
df = pd.DataFrame(survey_data, columns=columns)

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
def to_percent(y, position): return f'{y:.0f}%'

# 그래프 생성
column_to_analyze = '주요_교통수단'
crosstab_data = pd.crosstab(df['연령대'], df[column_to_analyze])
crosstab_data_norm = crosstab_data.div(crosstab_data.sum(axis=1), axis=0) * 100
fig, ax = plt.subplots(figsize=(14, 8))
crosstab_data_norm.plot(kind='bar', ax=ax, rot=0)
plt.title(f'연령대별 {column_to_analyze} 선택 비율', fontsize=16)
plt.xlabel('연령대', fontsize=12)
plt.ylabel('비율', fontsize=12)
formatter = FuncFormatter(to_percent)
ax.yaxis.set_major_formatter(formatter)
plt.legend(title=column_to_analyze, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout(rect=[0, 0, 0.95, 1])
plt.savefig(f'연령대별_{column_to_analyze}_그룹_막대_그래프.png')
print(f"'연령대별_{column_to_analyze}_그룹_막대_그래프.png' 파일이 생성되었습니다.")
# Out:
# '연령대별_주요_교통수단_그룹_막대_그래프.png' 파일이 생성되었습니다.

# %% [markdown]
# # 7. 연령대별 휴가_기간 건수 비율

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# --- 데이터 생성 코드 ---
options = {'age': ['10대', '20대', '30대', '40대', '50대', '60대 이상'], 'gender': ['남성', '여성'], 'vacation_type': ['해수욕, 물놀이 (바다/섬 여행)', '등산, 캠핑 등 아웃도어 활동 (산/계곡 여행)', '문화생활 (전시, 공연, 역사 탐방, 축제 등)', '도시 관광 (쇼핑, 카페, 시내 구경)', '휴양·힐링 (스파, 리조트, 펜션 휴식)', '맛집 투어 (맛집 탐방, 지역 특산물 체험)', '친척·지인 방문', '기타(결측치 처리)'], 'location_domestic': ['서울', '부산', '대구', '대전', '광주', '울산', '인천', '세종', '강원', '경북', '경남', '전북', '전남', '충북', '충남', '제주'], 'location_overseas': ['동아시아', '동남아시아', '서유럽', '동유럽', '북미', '남미', '중동', '오세아니아', '아프리카'], 'transportation': ['자동차', '버스', '기차', '항공편', '배(선박)', '도보'], 'duration': ['1일', '2~3일', '4~6일', '7일~ 15일', '15일 이상'], 'companions': ['혼자', '가족', '친구', '연인', '직장 동료', '동호회', '기타(결측치 처리)'], 'cost': ['10만 원 이하', '10만~30만 원', '30만~50만 원', '50만~100만 원', '100만 원~200만 원', '200만 원 이상'], 'satisfaction': ['매우 만족', '만족', '보통', '불만족', '매우 불만족']}
age_probs = {'10대': {'age': 0.05, 'vacation_type_p': [0.4, 0.05, 0.1, 0.2, 0.1, 0.1, 0.04, 0.01], 'location_p': [0.7, 0.3], 'transportation_p': [0.2, 0.1, 0.1, 0.25, 0.05, 0.3], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.05, 0.5, 0.35, 0.05, 0.01, 0.03, 0.01], 'cost_p': [0.3, 0.3, 0.2, 0.1, 0.05, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '20대': {'age': 0.25, 'vacation_type_p': [0.3, 0.05, 0.15, 0.2, 0.1, 0.15, 0.04, 0.01], 'location_p': [0.65, 0.35], 'transportation_p': [0.3, 0.1, 0.1, 0.35, 0.05, 0.1], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.15, 0.25, 0.25, 0.25, 0.05, 0.04, 0.01], 'cost_p': [0.1, 0.2, 0.3, 0.2, 0.15, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '30대': {'age': 0.25, 'vacation_type_p': [0.25, 0.1, 0.1, 0.1, 0.25, 0.1, 0.09, 0.01], 'location_p': [0.8, 0.2], 'transportation_p': [0.6, 0.05, 0.1, 0.1, 0.05, 0.1], 'duration_p': [0.05, 0.35, 0.3, 0.2, 0.1], 'companions_p': [0.05, 0.65, 0.15, 0.1, 0.03, 0.01, 0.01], 'cost_p': [0.05, 0.15, 0.25, 0.3, 0.2, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '40대': {'age': 0.2, 'vacation_type_p': [0.2, 0.2, 0.1, 0.05, 0.2, 0.1, 0.14, 0.01], 'location_p': [0.85, 0.15], 'transportation_p': [0.7, 0.1, 0.05, 0.05, 0.05, 0.05], 'duration_p': [0.05, 0.3, 0.3, 0.25, 0.1], 'companions_p': [0.05, 0.7, 0.1, 0.05, 0.05, 0.04, 0.01], 'cost_p': [0.05, 0.1, 0.2, 0.25, 0.25, 0.15], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '50대': {'age': 0.15, 'vacation_type_p': [0.1, 0.3, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.9, 0.1], 'transportation_p': [0.75, 0.1, 0.05, 0.02, 0.05, 0.03], 'duration_p': [0.05, 0.25, 0.3, 0.25, 0.15], 'companions_p': [0.03, 0.6, 0.05, 0.02, 0.2, 0.05, 0.05], 'cost_p': [0.05, 0.1, 0.15, 0.2, 0.25, 0.25], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '60대 이상': {'age': 0.1, 'vacation_type_p': [0.05, 0.35, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.95, 0.05], 'transportation_p': [0.8, 0.1, 0.05, 0.01, 0.03, 0.01], 'duration_p': [0.1, 0.2, 0.25, 0.25, 0.2], 'companions_p': [0.02, 0.5, 0.03, 0.01, 0.3, 0.05, 0.09], 'cost_p': [0.1, 0.1, 0.1, 0.15, 0.25, 0.3], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}}
survey_data = []
for _ in range(500): age = np.random.choice(options['age'], p=[age_probs[a]['age'] for a in options['age']]); probs = age_probs[age]; gender = np.random.choice(options['gender']); vacation_type = np.random.choice(options['vacation_type'], p=probs['vacation_type_p']); location_type = np.random.choice(['국내', '해외'], p=probs['location_p']); location = np.random.choice(options['location_domestic']) if location_type == '국내' else np.random.choice(options['location_overseas']); transportation = np.random.choice(options['transportation'], p=probs['transportation_p']); duration = np.random.choice(options['duration'], p=probs['duration_p']); companions = np.random.choice(options['companions'], p=probs['companions_p']); cost = np.random.choice(options['cost'], p=probs['cost_p']); satisfaction = np.random.choice(options['satisfaction'], p=probs['satisfaction_p']); next_vacation = np.random.choice(options['vacation_type']); survey_data.append([age, gender, vacation_type, location_type, location, transportation, duration, companions, cost, satisfaction, next_vacation])
columns = ['연령대', '성별', '가장_최근_여름_휴가', '휴가_장소_국내_해외', '휴가_장소', '주요_교통수단', '휴가_기간', '함께한_사람', '총_비용', '만족도', '다음_휴가_경험']
df = pd.DataFrame(survey_data, columns=columns)

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
def to_percent(y, position): return f'{y:.0f}%'

# 그래프 생성
column_to_analyze = '휴가_기간'
crosstab_data = pd.crosstab(df['연령대'], df[column_to_analyze])
crosstab_data_norm = crosstab_data.div(crosstab_data.sum(axis=1), axis=0) * 100
fig, ax = plt.subplots(figsize=(14, 8))
crosstab_data_norm.plot(kind='bar', ax=ax, rot=0)
plt.title(f'연령대별 {column_to_analyze} 선택 비율', fontsize=16)
plt.xlabel('연령대', fontsize=12)
plt.ylabel('비율', fontsize=12)
formatter = FuncFormatter(to_percent)
ax.yaxis.set_major_formatter(formatter)
plt.legend(title=column_to_analyze, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout(rect=[0, 0, 0.95, 1])
plt.savefig(f'연령대별_{column_to_analyze}_그룹_막대_그래프.png')
print(f"'연령대별_{column_to_analyze}_그룹_막대_그래프.png' 파일이 생성되었습니다.")
# Out:
# '연령대별_휴가_기간_그룹_막대_그래프.png' 파일이 생성되었습니다.

# %% [markdown]
# # 8. 연령대별 휴가_장소_국내_해외 건수 비율

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# --- 데이터 생성 코드 ---
options = {'age': ['10대', '20대', '30대', '40대', '50대', '60대 이상'], 'gender': ['남성', '여성'], 'vacation_type': ['해수욕, 물놀이 (바다/섬 여행)', '등산, 캠핑 등 아웃도어 활동 (산/계곡 여행)', '문화생활 (전시, 공연, 역사 탐방, 축제 등)', '도시 관광 (쇼핑, 카페, 시내 구경)', '휴양·힐링 (스파, 리조트, 펜션 휴식)', '맛집 투어 (맛집 탐방, 지역 특산물 체험)', '친척·지인 방문', '기타(결측치 처리)'], 'location_domestic': ['서울', '부산', '대구', '대전', '광주', '울산', '인천', '세종', '강원', '경북', '경남', '전북', '전남', '충북', '충남', '제주'], 'location_overseas': ['동아시아', '동남아시아', '서유럽', '동유럽', '북미', '남미', '중동', '오세아니아', '아프리카'], 'transportation': ['자동차', '버스', '기차', '항공편', '배(선박)', '도보'], 'duration': ['1일', '2~3일', '4~6일', '7일~ 15일', '15일 이상'], 'companions': ['혼자', '가족', '친구', '연인', '직장 동료', '동호회', '기타(결측치 처리)'], 'cost': ['10만 원 이하', '10만~30만 원', '30만~50만 원', '50만~100만 원', '100만 원~200만 원', '200만 원 이상'], 'satisfaction': ['매우 만족', '만족', '보통', '불만족', '매우 불만족']}
age_probs = {'10대': {'age': 0.05, 'vacation_type_p': [0.4, 0.05, 0.1, 0.2, 0.1, 0.1, 0.04, 0.01], 'location_p': [0.7, 0.3], 'transportation_p': [0.2, 0.1, 0.1, 0.25, 0.05, 0.3], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.05, 0.5, 0.35, 0.05, 0.01, 0.03, 0.01], 'cost_p': [0.3, 0.3, 0.2, 0.1, 0.05, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '20대': {'age': 0.25, 'vacation_type_p': [0.3, 0.05, 0.15, 0.2, 0.1, 0.15, 0.04, 0.01], 'location_p': [0.65, 0.35], 'transportation_p': [0.3, 0.1, 0.1, 0.35, 0.05, 0.1], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.15, 0.25, 0.25, 0.25, 0.05, 0.04, 0.01], 'cost_p': [0.1, 0.2, 0.3, 0.2, 0.15, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '30대': {'age': 0.25, 'vacation_type_p': [0.25, 0.1, 0.1, 0.1, 0.25, 0.1, 0.09, 0.01], 'location_p': [0.8, 0.2], 'transportation_p': [0.6, 0.05, 0.1, 0.1, 0.05, 0.1], 'duration_p': [0.05, 0.35, 0.3, 0.2, 0.1], 'companions_p': [0.05, 0.65, 0.15, 0.1, 0.03, 0.01, 0.01], 'cost_p': [0.05, 0.15, 0.25, 0.3, 0.2, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '40대': {'age': 0.2, 'vacation_type_p': [0.2, 0.2, 0.1, 0.05, 0.2, 0.1, 0.14, 0.01], 'location_p': [0.85, 0.15], 'transportation_p': [0.7, 0.1, 0.05, 0.05, 0.05, 0.05], 'duration_p': [0.05, 0.3, 0.3, 0.25, 0.1], 'companions_p': [0.05, 0.7, 0.1, 0.05, 0.05, 0.04, 0.01], 'cost_p': [0.05, 0.1, 0.2, 0.25, 0.25, 0.15], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '50대': {'age': 0.15, 'vacation_type_p': [0.1, 0.3, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.9, 0.1], 'transportation_p': [0.75, 0.1, 0.05, 0.02, 0.05, 0.03], 'duration_p': [0.05, 0.25, 0.3, 0.25, 0.15], 'companions_p': [0.03, 0.6, 0.05, 0.02, 0.2, 0.05, 0.05], 'cost_p': [0.05, 0.1, 0.15, 0.2, 0.25, 0.25], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '60대 이상': {'age': 0.1, 'vacation_type_p': [0.05, 0.35, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.95, 0.05], 'transportation_p': [0.8, 0.1, 0.05, 0.01, 0.03, 0.01], 'duration_p': [0.1, 0.2, 0.25, 0.25, 0.2], 'companions_p': [0.02, 0.5, 0.03, 0.01, 0.3, 0.05, 0.09], 'cost_p': [0.1, 0.1, 0.1, 0.15, 0.25, 0.3], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}}
survey_data = []
for _ in range(500): age = np.random.choice(options['age'], p=[age_probs[a]['age'] for a in options['age']]); probs = age_probs[age]; gender = np.random.choice(options['gender']); vacation_type = np.random.choice(options['vacation_type'], p=probs['vacation_type_p']); location_type = np.random.choice(['국내', '해외'], p=probs['location_p']); location = np.random.choice(options['location_domestic']) if location_type == '국내' else np.random.choice(options['location_overseas']); transportation = np.random.choice(options['transportation'], p=probs['transportation_p']); duration = np.random.choice(options['duration'], p=probs['duration_p']); companions = np.random.choice(options['companions'], p=probs['companions_p']); cost = np.random.choice(options['cost'], p=probs['cost_p']); satisfaction = np.random.choice(options['satisfaction'], p=probs['satisfaction_p']); next_vacation = np.random.choice(options['vacation_type']); survey_data.append([age, gender, vacation_type, location_type, location, transportation, duration, companions, cost, satisfaction, next_vacation])
columns = ['연령대', '성별', '가장_최근_여름_휴가', '휴가_장소_국내_해외', '휴가_장소', '주요_교통수단', '휴가_기간', '함께한_사람', '총_비용', '만족도', '다음_휴가_경험']
df = pd.DataFrame(survey_data, columns=columns)

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
def to_percent(y, position): return f'{y:.0f}%'

# 그래프 생성
column_to_analyze = '휴가_장소_국내_해외'
crosstab_data = pd.crosstab(df['연령대'], df[column_to_analyze])
crosstab_data_norm = crosstab_data.div(crosstab_data.sum(axis=1), axis=0) * 100
fig, ax = plt.subplots(figsize=(10, 6))
crosstab_data_norm.plot(kind='bar', ax=ax, rot=0)
plt.title(f'연령대별 {column_to_analyze} 선택 비율', fontsize=16)
plt.xlabel('연령대', fontsize=12)
plt.ylabel('비율', fontsize=12)
formatter = FuncFormatter(to_percent)
ax.yaxis.set_major_formatter(formatter)
plt.legend(title=column_to_analyze, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout(rect=[0, 0, 0.95, 1])
plt.savefig(f'연령대별_{column_to_analyze}_그룹_막대_그래프.png')
print(f"'연령대별_{column_to_analyze}_그룹_막대_그래프.png' 파일이 생성되었습니다.")
# Out:
# '연령대별_휴가_장소_국내_해외_그룹_막대_그래프.png' 파일이 생성되었습니다.

# %% [markdown]
# # 9. 연령대별 함께한_사람 건수 비율

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# --- 데이터 생성 코드 ---
options = {'age': ['10대', '20대', '30대', '40대', '50대', '60대 이상'], 'gender': ['남성', '여성'], 'vacation_type': ['해수욕, 물놀이 (바다/섬 여행)', '등산, 캠핑 등 아웃도어 활동 (산/계곡 여행)', '문화생활 (전시, 공연, 역사 탐방, 축제 등)', '도시 관광 (쇼핑, 카페, 시내 구경)', '휴양·힐링 (스파, 리조트, 펜션 휴식)', '맛집 투어 (맛집 탐방, 지역 특산물 체험)', '친척·지인 방문', '기타(결측치 처리)'], 'location_domestic': ['서울', '부산', '대구', '대전', '광주', '울산', '인천', '세종', '강원', '경북', '경남', '전북', '전남', '충북', '충남', '제주'], 'location_overseas': ['동아시아', '동남아시아', '서유럽', '동유럽', '북미', '남미', '중동', '오세아니아', '아프리카'], 'transportation': ['자동차', '버스', '기차', '항공편', '배(선박)', '도보'], 'duration': ['1일', '2~3일', '4~6일', '7일~ 15일', '15일 이상'], 'companions': ['혼자', '가족', '친구', '연인', '직장 동료', '동호회', '기타(결측치 처리)'], 'cost': ['10만 원 이하', '10만~30만 원', '30만~50만 원', '50만~100만 원', '100만 원~200만 원', '200만 원 이상'], 'satisfaction': ['매우 만족', '만족', '보통', '불만족', '매우 불만족']}
age_probs = {'10대': {'age': 0.05, 'vacation_type_p': [0.4, 0.05, 0.1, 0.2, 0.1, 0.1, 0.04, 0.01], 'location_p': [0.7, 0.3], 'transportation_p': [0.2, 0.1, 0.1, 0.25, 0.05, 0.3], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.05, 0.5, 0.35, 0.05, 0.01, 0.03, 0.01], 'cost_p': [0.3, 0.3, 0.2, 0.1, 0.05, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '20대': {'age': 0.25, 'vacation_type_p': [0.3, 0.05, 0.15, 0.2, 0.1, 0.15, 0.04, 0.01], 'location_p': [0.65, 0.35], 'transportation_p': [0.3, 0.1, 0.1, 0.35, 0.05, 0.1], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.15, 0.25, 0.25, 0.25, 0.05, 0.04, 0.01], 'cost_p': [0.1, 0.2, 0.3, 0.2, 0.15, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '30대': {'age': 0.25, 'vacation_type_p': [0.25, 0.1, 0.1, 0.1, 0.25, 0.1, 0.09, 0.01], 'location_p': [0.8, 0.2], 'transportation_p': [0.6, 0.05, 0.1, 0.1, 0.05, 0.1], 'duration_p': [0.05, 0.35, 0.3, 0.2, 0.1], 'companions_p': [0.05, 0.65, 0.15, 0.1, 0.03, 0.01, 0.01], 'cost_p': [0.05, 0.15, 0.25, 0.3, 0.2, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '40대': {'age': 0.2, 'vacation_type_p': [0.2, 0.2, 0.1, 0.05, 0.2, 0.1, 0.14, 0.01], 'location_p': [0.85, 0.15], 'transportation_p': [0.7, 0.1, 0.05, 0.05, 0.05, 0.05], 'duration_p': [0.05, 0.3, 0.3, 0.25, 0.1], 'companions_p': [0.05, 0.7, 0.1, 0.05, 0.05, 0.04, 0.01], 'cost_p': [0.05, 0.1, 0.2, 0.25, 0.25, 0.15], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '50대': {'age': 0.15, 'vacation_type_p': [0.1, 0.3, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.9, 0.1], 'transportation_p': [0.75, 0.1, 0.05, 0.02, 0.05, 0.03], 'duration_p': [0.05, 0.25, 0.3, 0.25, 0.15], 'companions_p': [0.03, 0.6, 0.05, 0.02, 0.2, 0.05, 0.05], 'cost_p': [0.05, 0.1, 0.15, 0.2, 0.25, 0.25], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '60대 이상': {'age': 0.1, 'vacation_type_p': [0.05, 0.35, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.95, 0.05], 'transportation_p': [0.8, 0.1, 0.05, 0.01, 0.03, 0.01], 'duration_p': [0.1, 0.2, 0.25, 0.25, 0.2], 'companions_p': [0.02, 0.5, 0.03, 0.01, 0.3, 0.05, 0.09], 'cost_p': [0.1, 0.1, 0.1, 0.15, 0.25, 0.3], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}}
survey_data = []
for _ in range(500): age = np.random.choice(options['age'], p=[age_probs[a]['age'] for a in options['age']]); probs = age_probs[age]; gender = np.random.choice(options['gender']); vacation_type = np.random.choice(options['vacation_type'], p=probs['vacation_type_p']); location_type = np.random.choice(['국내', '해외'], p=probs['location_p']); location = np.random.choice(options['location_domestic']) if location_type == '국내' else np.random.choice(options['location_overseas']); transportation = np.random.choice(options['transportation'], p=probs['transportation_p']); duration = np.random.choice(options['duration'], p=probs['duration_p']); companions = np.random.choice(options['companions'], p=probs['companions_p']); cost = np.random.choice(options['cost'], p=probs['cost_p']); satisfaction = np.random.choice(options['satisfaction'], p=probs['satisfaction_p']); next_vacation = np.random.choice(options['vacation_type']); survey_data.append([age, gender, vacation_type, location_type, location, transportation, duration, companions, cost, satisfaction, next_vacation])
columns = ['연령대', '성별', '가장_최근_여름_휴가', '휴가_장소_국내_해외', '휴가_장소', '주요_교통수단', '휴가_기간', '함께한_사람', '총_비용', '만족도', '다음_휴가_경험']
df = pd.DataFrame(survey_data, columns=columns)

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
def to_percent(y, position): return f'{y:.0f}%'

# 그래프 생성
column_to_analyze = '함께한_사람'
crosstab_data = pd.crosstab(df['연령대'], df[column_to_analyze])
crosstab_data_norm = crosstab_data.div(crosstab_data.sum(axis=1), axis=0) * 100
fig, ax = plt.subplots(figsize=(14, 8))
crosstab_data_norm.plot(kind='bar', ax=ax, rot=0)
plt.title(f'연령대별 {column_to_analyze} 선택 비율', fontsize=16)
plt.xlabel('연령대', fontsize=12)
plt.ylabel('비율', fontsize=12)
formatter = FuncFormatter(to_percent)
ax.yaxis.set_major_formatter(formatter)
plt.legend(title=column_to_analyze, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout(rect=[0, 0, 0.95, 1])
plt.savefig(f'연령대별_{column_to_analyze}_그룹_막대_그래프.png')
print(f"'연령대별_{column_to_analyze}_그룹_막대_그래프.png' 파일이 생성되었습니다.")
# Out:
# '연령대별_함께한_사람_그룹_막대_그래프.png' 파일이 생성되었습니다.

# %% [markdown]
# # 10. 휴가_장소 건수 (바코드 그래프)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- 데이터 생성 코드 ---
options = {'age': ['10대', '20대', '30대', '40대', '50대', '60대 이상'], 'gender': ['남성', '여성'], 'vacation_type': ['해수욕, 물놀이 (바다/섬 여행)', '등산, 캠핑 등 아웃도어 활동 (산/계곡 여행)', '문화생활 (전시, 공연, 역사 탐방, 축제 등)', '도시 관광 (쇼핑, 카페, 시내 구경)', '휴양·힐링 (스파, 리조트, 펜션 휴식)', '맛집 투어 (맛집 탐방, 지역 특산물 체험)', '친척·지인 방문', '기타(결측치 처리)'], 'location_domestic': ['서울', '부산', '대구', '대전', '광주', '울산', '인천', '세종', '강원', '경북', '경남', '전북', '전남', '충북', '충남', '제주'], 'location_overseas': ['동아시아', '동남아시아', '서유럽', '동유럽', '북미', '남미', '중동', '오세아니아', '아프리카'], 'transportation': ['자동차', '버스', '기차', '항공편', '배(선박)', '도보'], 'duration': ['1일', '2~3일', '4~6일', '7일~ 15일', '15일 이상'], 'companions': ['혼자', '가족', '친구', '연인', '직장 동료', '동호회', '기타(결측치 처리)'], 'cost': ['10만 원 이하', '10만~30만 원', '30만~50만 원', '50만~100만 원', '100만 원~200만 원', '200만 원 이상'], 'satisfaction': ['매우 만족', '만족', '보통', '불만족', '매우 불만족']}
age_probs = {'10대': {'age': 0.05, 'vacation_type_p': [0.4, 0.05, 0.1, 0.2, 0.1, 0.1, 0.04, 0.01], 'location_p': [0.7, 0.3], 'transportation_p': [0.2, 0.1, 0.1, 0.25, 0.05, 0.3], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.05, 0.5, 0.35, 0.05, 0.01, 0.03, 0.01], 'cost_p': [0.3, 0.3, 0.2, 0.1, 0.05, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '20대': {'age': 0.25, 'vacation_type_p': [0.3, 0.05, 0.15, 0.2, 0.1, 0.15, 0.04, 0.01], 'location_p': [0.65, 0.35], 'transportation_p': [0.3, 0.1, 0.1, 0.35, 0.05, 0.1], 'duration_p': [0.1, 0.4, 0.3, 0.15, 0.05], 'companions_p': [0.15, 0.25, 0.25, 0.25, 0.05, 0.04, 0.01], 'cost_p': [0.1, 0.2, 0.3, 0.2, 0.15, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '30대': {'age': 0.25, 'vacation_type_p': [0.25, 0.1, 0.1, 0.1, 0.25, 0.1, 0.09, 0.01], 'location_p': [0.8, 0.2], 'transportation_p': [0.6, 0.05, 0.1, 0.1, 0.05, 0.1], 'duration_p': [0.05, 0.35, 0.3, 0.2, 0.1], 'companions_p': [0.05, 0.65, 0.15, 0.1, 0.03, 0.01, 0.01], 'cost_p': [0.05, 0.15, 0.25, 0.3, 0.2, 0.05], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '40대': {'age': 0.2, 'vacation_type_p': [0.2, 0.2, 0.1, 0.05, 0.2, 0.1, 0.14, 0.01], 'location_p': [0.85, 0.15], 'transportation_p': [0.7, 0.1, 0.05, 0.05, 0.05, 0.05], 'duration_p': [0.05, 0.3, 0.3, 0.25, 0.1], 'companions_p': [0.05, 0.7, 0.1, 0.05, 0.05, 0.04, 0.01], 'cost_p': [0.05, 0.1, 0.2, 0.25, 0.25, 0.15], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '50대': {'age': 0.15, 'vacation_type_p': [0.1, 0.3, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.9, 0.1], 'transportation_p': [0.75, 0.1, 0.05, 0.02, 0.05, 0.03], 'duration_p': [0.05, 0.25, 0.3, 0.25, 0.15], 'companions_p': [0.03, 0.6, 0.05, 0.02, 0.2, 0.05, 0.05], 'cost_p': [0.05, 0.1, 0.15, 0.2, 0.25, 0.25], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}, '60대 이상': {'age': 0.1, 'vacation_type_p': [0.05, 0.35, 0.1, 0.05, 0.15, 0.05, 0.2, 0.05], 'location_p': [0.95, 0.05], 'transportation_p': [0.8, 0.1, 0.05, 0.01, 0.03, 0.01], 'duration_p': [0.1, 0.2, 0.25, 0.25, 0.2], 'companions_p': [0.02, 0.5, 0.03, 0.01, 0.3, 0.05, 0.09], 'cost_p': [0.1, 0.1, 0.1, 0.15, 0.25, 0.3], 'satisfaction_p': [0.3, 0.4, 0.2, 0.05, 0.05]}}
survey_data = []
for _ in range(500): age = np.random.choice(options['age'], p=[age_probs[a]['age'] for a in options['age']]); probs = age_probs[age]; gender = np.random.choice(options['gender']); vacation_type = np.random.choice(options['vacation_type'], p=probs['vacation_type_p']); location_type = np.random.choice(['국내', '해외'], p=probs['location_p']); location = np.random.choice(options['location_domestic']) if location_type == '국내' else np.random.choice(options['location_overseas']); transportation = np.random.choice(options['transportation'], p=probs['transportation_p']); duration = np.random.choice(options['duration'], p=probs['duration_p']); companions = np.random.choice(options['companions'], p=probs['companions_p']); cost = np.random.choice(options['cost'], p=probs['cost_p']); satisfaction = np.random.choice(options['satisfaction'], p=probs['satisfaction_p']); next_vacation = np.random.choice(options['vacation_type']); survey_data.append([age, gender, vacation_type, location_type, location, transportation, duration, companions, cost, satisfaction, next_vacation])
columns = ['연령대', '성별', '가장_최근_여름_휴가', '휴가_장소_국내_해외', '휴가_장소', '주요_교통수단', '휴가_기간', '함께한_사람', '총_비용', '만족도', '다음_휴가_경험']
df = pd.DataFrame(survey_data, columns=columns)

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
def to_percent(y, position): return f'{y:.0f}%'

# 그래프 생성
column_to_analyze = '휴가_장소'
location_counts = df[column_to_analyze].value_counts().sort_values(ascending=True)
plt.figure(figsize=(10, 18))
plt.hlines(y=location_counts.index, xmin=0, xmax=location_counts.values, color='skyblue', linewidth=2)
plt.plot(location_counts.values, location_counts.index, "o", color='darkblue')
plt.title('휴가 장소별 건수 (바코드 그래프)', fontsize=16)
plt.xlabel('건수', fontsize=12)
plt.ylabel('휴가 장소', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig('휴가_장소_바코드_그래프.png')
print("바코드 그래프가 '휴가_장소_바코드_그래프.png' 파일로 생성되었습니다.")
# Out:
# 바코드 그래프가 '휴가_장소_바코드_그래프.png' 파일로 생성되었습니다.
